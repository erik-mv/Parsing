# %%
url = 'https://100-faktov.ru/wp-content/uploads/2017/10/134b05dfe0d696d558d9.jpg'

# %% [markdown]
# ## Пример загрузки и сохранения картинки через `requects`

# %%
import requests

# %%
response = requests.get(url)

# %%
with open('example.jpg', 'wb') as f:
  f.write(response.content)

# %% [markdown]
# ## Пример загрузки и сохранения картинки через `wget`

# %% [markdown]
# ### Через командную строку

# %%
# !wget https://100-faktov.ru/wp-content/uploads/2017/10/134b05dfe0d696d558d9.jpg
# Out:
# --2022-09-13 17:20:48--  https://100-faktov.ru/wp-content/uploads/2017/10/134b05dfe0d696d558d9.jpg
# Resolving 100-faktov.ru (100-faktov.ru)... 87.236.16.74
# Connecting to 100-faktov.ru (100-faktov.ru)|87.236.16.74|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1577179 (1.5M) [image/jpeg]
# Saving to: ‘134b05dfe0d696d558d9.jpg’
#
# 134b05dfe0d696d558d 100%[===================>]   1.50M  2.04MB/s    in 0.7s
#
# 2022-09-13 17:20:49 (2.04 MB/s) - ‘134b05dfe0d696d558d9.jpg’ saved [1577179/1577179]

# %% [markdown]
# ### Через python

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=d198a4f4d23309e57e1912491d741d82daea7261d0f056525666aa296d22e9f1
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
import wget

# %%
wget.download(url)
# Out:
# '134b05dfe0d696d558d9 (2).jpg'
