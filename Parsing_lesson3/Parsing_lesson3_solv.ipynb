# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'

URL_FIRST_PAGE_HH = 'https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20'

# %%
headers = {
    'User-Agent': USER_AGENT,
}

# %%
def parse_hh(url_page, headers, result=[], index_page=1):
    response = requests.get(url_page, headers=headers)
    if response.status_code != 200:
      print('Парсинг завершен')
      return result
    else:
      print('Cтраница №%d, ссылка: %s'%(index_page, response.url))

    dom = bs(response.content, 'html.parser')
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
      result.append(parse_vacancy_hh(vacancy))

    link_next_page = dom.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
      link_next_page =  'https://spb.hh.ru' + link_next_page['href']
    else:
      print('Парсинг завершен')
      return result

    result = parse_hh(link_next_page, headers, result, index_page+1)   
    return result
     
def parse_vacancy_hh(dom_vacancy):
  sleep(0.1)
  vacancy_name = dom_vacancy.find('a').text

  vacancy_salary = dom_vacancy.find('span', {'class', 'bloko-header-section-3'})
  if vacancy_salary:
    vacancy_salary = vacancy_salary.text
    min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
  else:
    min_salary, max_salary, currency_salary = None, None, None

  vacancy_link = dom_vacancy.find('a')['href']
  
  return {
      'vacancy_name': vacancy_name,
      'vacancy_salary': vacancy_salary,
      'min_salary': min_salary,
      'max_salary': max_salary,
      'currency_salary': currency_salary,
      'vacancy_link': vacancy_link,
      'vacancy_source': 'hh.ru',
  }

def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
result = parse_hh(URL_FIRST_PAGE_HH, headers)
# Out:
# Cтраница №1, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20
# Cтраница №2, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=1&hhtmFrom=vacancy_search_list
# Cтраница №3, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=2&hhtmFrom=vacancy_search_list
# Cтраница №4, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=3&hhtmFrom=vacancy_search_list
# Cтраница №5, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=4&hhtmFrom=vacancy_search_list
# Cтраница №6, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=5&hhtmFrom=vacancy_search_list
# Cтраница №7, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=6&hhtmFrom=vacancy_search_list
# Cтраница №8, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=7&hhtmFrom=vacancy_search_list
# Cтраница №9, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=8&hhtmFrom=vacancy_search_list
# Cтраница №10, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=9&hhtmFrom=vacancy_search_list
# Парсинг завершен

# %%
len(result)
# Out:
# 200

# %%
result
# Out:
# [{'vacancy_name': 'Python-разработчик (Django)',
#   'vacancy_salary': 'до 175\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 175000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69694383?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик',
#   'vacancy_salary': 'от 350\u202f000 руб.',
#   'min_salary': 350000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69666315?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Python Developer',
#   'vacancy_salary': '130\u202f000 – 250\u202f000 руб.',
#   'min_salary': 130000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69037494?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python Middle Backend Developer (FastAPI)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67173564?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69711589?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Team Lead Python',
#   'vacancy_salary': 'от 6\u202f500 USD',
#   'min_salary': 6500,
#   'max_salary': None,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69431363?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': '2\u202f000 – 4\u202f000 USD',
#   'min_salary': 2000,
#   'max_salary': 4000,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69730636?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data scientist',
#   'vacancy_salary': '50\u202f000 – 150\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69694041?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69704119?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель программирования',
#   'vacancy_salary': 'до 50\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69686857?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior/Middle QA specialist (ручное / автотесты) Python',
#   'vacancy_salary': '200\u202f000 – 255\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 255000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68800644?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle python разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68771933?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68700013?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист Python',
#   'vacancy_salary': '150\u202f000 – 210\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 210000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69250635?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель Web-разработки на Python+JavaScript',
#   'vacancy_salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69593051?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68662840?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик Python',
#   'vacancy_salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69163405?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle/Senior Python-разработчик в команду Добычи данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66066365?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend - разработчик (Python, Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69339814?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик (Внутренние проекты)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67713096?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик SQL (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67989355?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python/Django разработчик',
#   'vacancy_salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69019002?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps Инженер',
#   'vacancy_salary': 'до 375\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 375000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68900033?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик Python (написание парсеров)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69123912?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68447733?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data analyst',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69049760?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель программирования Python для детей',
#   'vacancy_salary': '40\u202f000 – 100\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69187443?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python (Big Data) Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68866792?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data Scientist',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68894494?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle/Senior Auto QA (Python) инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69296359?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель программирования Python для детей онлайн',
#   'vacancy_salary': '40\u202f000 – 100\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68215742?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик в команду сетей облака',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68199533?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель курсов программирования онлайн',
#   'vacancy_salary': '40\u202f000 – 100\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67987841?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель программирования Python/C++ для детей онлайн',
#   'vacancy_salary': '40\u202f000 – 100\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67987546?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer (Django)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66108672?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Стажер-инженер Linux (системы мониторинга, рабочие места)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68795790?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'FullStack QA Engineer (Python)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67883836?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'RPA - разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69709722?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик SQL (российская ИТ компания, удалённая работа)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69504960?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Devops - инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69500391?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data Science engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67174007?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps / SRE Specialist',
#   'vacancy_salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69341281?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик (Django, DRF, удаленно)',
#   'vacancy_salary': '60\u202f000 – 150\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69303993?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Стажер Big Data',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69137053?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IT-тренер на обучение слушателей курса «Программная инженерия. Управление разработкой ПО»',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69709177?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Big Data Engineer with Spark (в UK)',
#   'vacancy_salary': 'от 6\u202f000 EUR',
#   'min_salary': 6000,
#   'max_salary': None,
#   'currency_salary': 'EUR',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68190560?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист С++ / Middle C++ Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69350071?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер данных DWH в Маркет',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69710886?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер (Казань)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66729881?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Platform Reliability Engineer',
#   'vacancy_salary': '1\u202f000 – 1\u202f500 USD',
#   'min_salary': 1000,
#   'max_salary': 1500,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69720386?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Go (Golang) Backend Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69704630?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер пробных уроков в офис (школа программирования)',
#   'vacancy_salary': '30\u202f000 – 70\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69390686?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик DWH в Тинькофф Азия',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68477522?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист по автотестированию',
#   'vacancy_salary': '70\u202f000 – 300\u202f000 руб.',
#   'min_salary': 70000,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69296924?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Пентестер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69705177?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технический специалист (онлайн-школа)',
#   'vacancy_salary': '30\u202f000 – 45\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69578578?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Data Scientist',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69706891?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор баз данных (DBA)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69702072?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Контест)',
#   'vacancy_salary': 'от 15\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/48224443?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик в Тинькофф Азия',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67772706?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор системы управления инженерными данными (СУИД, HxGN, SDX)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68657085?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior С++ Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69738548?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Engineer (Backend)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68700002?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Team Lead QA',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69587953?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Engineer (Web)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68700000?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-проектировщик (Системы безопасности)',
#   'vacancy_salary': 'от 400\u202f000 руб.',
#   'min_salary': 400000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67433515?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'CTO / Директор IT (EdTech)',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69649442?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Бизнес-аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68771948?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Lead (remote)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68851609?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий инженер АСУ ТП Yokogawa (Centum, Prosafe, Stardom)',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/55056476?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий инженер АСУ ТП',
#   'vacancy_salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69316211?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист технической поддержки',
#   'vacancy_salary': 'от 15\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69711861?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ночной специалист технической поддержки',
#   'vacancy_salary': '18\u202f000 – 36\u202f000 руб.',
#   'min_salary': 18000,
#   'max_salary': 36000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69704338?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий инженер АСУТП (ПТК DeltaV)',
#   'vacancy_salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69316288?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-Конструктор ПГС (AUTODESK REVIT)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/54687546?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель направления автоматизации Linux-систем',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69663731?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик C++ в команду поиска Маркета',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68737588?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по направлению сетевой автоматизации (middle, junior)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67642248?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Web-программист',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68350522?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик в Инфраструктуру Поиска Маркета С++',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68737664?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Дата - аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69636930?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69630772?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior QA Engineer AI/ML (to Armenia / Portugal)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67628312?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA automation (R&D)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69621362?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сетевой администратор',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69634543?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69602247?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик кадрового департамента',
#   'vacancy_salary': 'от 70\u202f000 руб.',
#   'min_salary': 70000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69604033?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист-тестировщик (отдел автотестирования)',
#   'vacancy_salary': '46\u202f000 – 92\u202f000 руб.',
#   'min_salary': 46000,
#   'max_salary': 92000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/55421319?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы прогнозирования (Data science), Ozon Fresh',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66725919?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель компьютерных курсов Малой Компьютерной Академии',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69573484?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный архитектор (информационная безопасность)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68547502?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Главный аналитик маркетинговых исследований',
#   'vacancy_salary': 'от 65\u202f300 руб.',
#   'min_salary': 65300,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66899204?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы инженеров (информационная безопасность)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68547471?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями',
#   'vacancy_salary': 'от 15\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68660851?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями в Яндекс Поиск',
#   'vacancy_salary': 'от 15\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68656418?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер отдела поддержки проектов (DevOps инженер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69543903?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Product Analyst (remote)',
#   'vacancy_salary': '2\u202f000 – 4\u202f000 USD',
#   'min_salary': 2000,
#   'max_salary': 4000,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69539415?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Младший специалист по аналитике',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69543464?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'NetOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68702828?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший аналитик',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69517493?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Devops Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68474088?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель направления безопасности кода',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69518191?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий Data Engineer (Ozon Fresh)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68967231?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист (C++, Linux)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/53914307?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps (Linux) engineer (удаленно)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69502530?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий разработчик Golang, Ozon Fresh',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/55510524?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель направления аналитики',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69494661?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle/Senior QA Automation инженер в команду 3D-карты',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69488998?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior C++ Developer (to Armenia)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66657707?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Software Engineer CI/CD, DevOps (to Armenia)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66656647?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сетевой инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69485682?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior PHP-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/53635898?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы тестирования',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69488655?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Software Engineer (SDET) to Armenia',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66658282?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps/CI инженер в сервис мобильных приложений',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67593475?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик операционной отчетности',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68355305?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Эксперт по технологии и моделированию',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67765596?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор технических средств SOC',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68509244?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор Linux серверов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68473600?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Data Scientist',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67488445?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер информационной безопасности в SOC',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69417804?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технический специалист в Yandex Pay Checkout',
#   'vacancy_salary': 'до 70\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69404855?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle/Senior QA-инженер в команду WebAPI',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67854176?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Lead в команду 3D-карты',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68765209?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор 2 линия',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69369250?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Full stack developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69351122?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик киберполигона (SOC)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68357179?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по безопасной разработке (AppSec инженер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69349629?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Cистемный администратор в команду облачного хранилища',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/54753257?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по сборке ПО',
#   'vacancy_salary': '44\u202f000 – 75\u202f000 руб.',
#   'min_salary': 44000,
#   'max_salary': 75000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67579963?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик Java',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69344277?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Principal Programmer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68464666?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик (SOC)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/45403221?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle C++ Developer (Gameplay)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68318626?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Executive Technical Director',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68465777?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Technical Director',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68466694?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный программист в отдел адаптации ОС Аврора',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67571292?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший аналитик BI',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69297929?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер системной интеграции',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68332060?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Бизнес-аналитик (Операционный маркетинг)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69289822?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Full-Stack Разработчик (react\\node.js)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69293775?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data Analyst',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69266876?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Помощник системного администратора Linux (Junior)',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69269354?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps Engineer ( to Limassol, Cyprus )',
#   'vacancy_salary': '4\u202f000 – 5\u202f000 EUR',
#   'min_salary': 4000,
#   'max_salary': 5000,
#   'currency_salary': 'EUR',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69267402?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по информационной безопасности',
#   'vacancy_salary': '2\u202f000 – 2\u202f400 USD',
#   'min_salary': 2000,
#   'max_salary': 2400,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69279100?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'BI Analyst/Data Analyst',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69268816?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель по программированию на Minecraft (онлайн)',
#   'vacancy_salary': '40\u202f000 – 60\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68865731?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель программирования / робототехники в детскую школу Инжинириум МГТУ (им. Баумана, Казань)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69238025?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий аналитик L3 (SOC)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68263819?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технический писатель (SOC)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68264361?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior developer (Team lead)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69229105?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы прогнозирования (Data science), Ozon Fresh',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69212273?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист АСУ ТП',
#   'vacancy_salary': 'до 235\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 235000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68968010?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Web-аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69215964?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик (SOC, Сети)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68197537?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA automation',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69220206?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67053678?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер проекта',
#   'vacancy_salary': '158\u202f000 – 335\u202f000 руб.',
#   'min_salary': 158000,
#   'max_salary': 335000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69220030?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68143593?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Specialist DevOps',
#   'vacancy_salary': 'до 280\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69142942?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps engineer',
#   'vacancy_salary': '4\u202f000 – 8\u202f000 USD',
#   'min_salary': 4000,
#   'max_salary': 8000,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69134152?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Specialist DevOps/Linux',
#   'vacancy_salary': 'до 150\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69143110?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Lead',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69170007?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data Analyst',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69124173?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер технической поддержки',
#   'vacancy_salary': 'от 70\u202f000 руб.',
#   'min_salary': 70000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69146854?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69131119?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Маркетинговый аналитик',
#   'vacancy_salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66113802?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Project manager / Менеджер проекта',
#   'vacancy_salary': '80\u202f000 – 150\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69145559?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Android Developer (middle)',
#   'vacancy_salary': '200\u202f000 – 250\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69120911?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps Engineer / SRE',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/53222134?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Devops TeamLead',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/51853033?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик (VueJS)',
#   'vacancy_salary': '120\u202f000 – 150\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69103155?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Tech Lead/Team Lead в команду Объектного хранилища',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69103776?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Team Lead в команду разработки выделенных серверов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66517069?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Пентестер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69011256?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior C++ Developer (Gameplay)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69009231?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Programming Team Lead (С++)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69009359?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Браузер)',
#   'vacancy_salary': 'от 15\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/48221819?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/54220301?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Automation Engineer / Инженер по автоматизации тестирования (middle/senior)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68968429?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Бизнес-аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68941691?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA инженер-сопровожденец',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68941260?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель направления настройки риск-стратегий',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68840550?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий программист DS/DE',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68836764?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Team Lead Unreal Engine',
#   'vacancy_salary': 'до 5\u202f000 USD',
#   'min_salary': None,
#   'max_salary': 5000,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68875518?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик по информационной безопасности (3-я линия SOC)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68887540?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'VOIP Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68881136?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший программист Oracle + Delphi',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67996463?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист для сопровождения ИТ-портала',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68856251?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер пробных уроков (школа программирования)',
#   'vacancy_salary': '30\u202f000 – 70\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68847926?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Product Analyst',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68843747?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный инженер Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68830585?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель направления разработки',
#   'vacancy_salary': '355\u202f000 – 520\u202f000 руб.',
#   'min_salary': 355000,
#   'max_salary': 520000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/51240861?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle DevOps',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67848168?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы сетевых инженеров.CCNP и выше',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67666796?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Яндекс ID)',
#   'vacancy_salary': 'от 15\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/48037479?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Automation Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/67994644?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист Full Stack',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68831090?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший разработчик Go, Базовые сервисы, Платформа',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68777623?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель по робототехнике и программированию',
#   'vacancy_salary': '5\u202f000 – 50\u202f000 руб.',
#   'min_salary': 5000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68757542?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'}]
