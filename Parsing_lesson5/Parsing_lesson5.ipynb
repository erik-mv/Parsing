# %% [markdown]
# # Урок 5
#
# # Парсинг данных. Scrapy. Начало

# %% [markdown]
# ## Загрузим проект

# %%
# !unzip scrapy.zip
# Out:
# Archive:  scrapy.zip
#    creating: scrapy/project_parser_hh/
#  extracting: scrapy/project_parser_hh/__init__.py
#   inflating: scrapy/project_parser_hh/items.py
#   inflating: scrapy/project_parser_hh/middlewares.py
#   inflating: scrapy/project_parser_hh/pipelines.py
#   inflating: scrapy/project_parser_hh/runner.py
#   inflating: scrapy/project_parser_hh/settings.py
#    creating: scrapy/project_parser_hh/spiders/
#   inflating: scrapy/project_parser_hh/spiders/__init__.py
#   inflating: scrapy/project_parser_hh/spiders/hh_ru.py
#   inflating: scrapy/scrapy.cfg

# %%
cd scrapy
# Out:
# /content/scrapy

# %% [markdown]
# ## Установим `mongo` сервер и клиент

# %%
# !apt install mongodb > log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Установим `scrapy`

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 264 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 66.4 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 19.6 MB/s
# ...
#      |████████████████████████████████| 251 kB 43.2 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.6 MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11958 sha256=2fb82dbd60f84165c2e9bb312beee4d883e95d66a08ef176e2098969b67bc187
#   Stored in directory: /root/.cache/pip/wheels/c9/d6/6a/de198d890277cde60ca3dbebe7ae592d3b381c7d9bb2455f4d
# Successfully built PyDispatcher
# ...

# %% [markdown]
# ## Запустим паука

# %%
# !scrapy crawl hh_ru
# Out:
# 2022-09-09 18:45:17 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: project_parser_hh)
# 2022-09-09 18:45:17 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.13 (default, Apr 24 2022, 01:04:09) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-09-09 18:45:17 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'project_parser_hh',
#  'DOWNLOAD_DELAY': 0.5,
#  'NEWSPIDER_MODULE': 'project_parser_hh.spiders',
#  'SPIDER_MODULES': ['project_parser_hh.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}
# 2022-09-09 18:45:17 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# ...

# %% [markdown]
# ## Проверим, что записалось в базу

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
print(client.list_database_names())
# Out:
# ['admin', 'local', 'vacancies_python_hh']

# %%
db = client.vacancies_python_hh
print(db.list_collection_names())
# Out:
# ['hh_ru']

# %%
collection_vacancies_hh_ru = db.hh_ru

# %%
vacancies_hh_ru_list = list(collection_vacancies_hh_ru.find())

# %% [markdown]
# ## Можно сравнить число вакансий по ссылкам
#
# [ссылка_1](https://spb.hh.ru/search/vacancy?area=76&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20)
#
# [ссылка_2](https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20)

# %%
len(vacancies_hh_ru_list)
# Out:
# 302

# %%
vacancies_hh_ru_list[:10] # первые 10
# Out:
# [{'_id': ObjectId('631b89c1b389e1ef0b0a8c6e'),
#   'name': 'Программист Python',
#   'salary': ['от ',
#    '50\xa0000',
#    ' до ',
#    '200\xa0000',
#    ' ',
#    'руб.',
#    ' ',
#    'на руки'],
#   'url': 'https://spb.hh.ru/vacancy/49488972?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python'},
#  {'_id': ObjectId('631b89c1b389e1ef0b0a8c6f'),
#   'name': 'DevOps / SRE Specialist',
#   'salary': ['от ', '250\xa0000', ' ', 'руб.', ' ', 'на руки'],
#   'url': 'https://spb.hh.ru/vacancy/69341280?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python'},
#  {'_id': ObjectId('631b89c2b389e1ef0b0a8c70'),
#   'name': 'Devops - инженер',
#   'salary': ['з/п не указана'],
#   'url': 'https://spb.hh.ru/vacancy/69500390?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python'},
#  {'_id': ObjectId('631b89c2b389e1ef0b0a8c71'),
#   'name': 'Разработчик SQL (российская ИТ компания, удалённая работа)',
#   'salary': ['з/п не указана'],
# ...
